# %% [markdown]
# # Simulation checks: sinusoid

# %%
# External modules.
import matplotlib.pyplot as plt
import numpy as np
import os

# Internal modules.
from setup.directories import img_path
from setup.sinusoid import Sinusoid
from setup.utils import makedir_safe
from setup.results import my_ext

# %%
# Create directory to save figures.
makedir_safe(img_path)

# %%
# Clerical setup.

## Seed control.
random_seed = 22993514079364 # fixed seed.
#random_seed = np.random.SeedSequence().entropy # uncomment for fresh seeds.

## Random generator (numpy).
rg = np.random.default_rng(random_seed)

## Dataset parameters.
n = 1000
data_weight_pair = [np.array([1.0,1.0]), np.array([-1.0,1.0])]
data_size = n
data_noise = 0.0

# %%
# Generate the data.
data = Sinusoid(rg=rg, weight_pair=data_weight_pair,
                size=data_size, noise=data_noise)
X, Y = data()
idx_0 = Y == 0
idx_1 = Y == 1
print(type(X), type(Y))
print(X.shape, Y.shape)
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (1000, 2) (1000,)

# %%
# Visualize the labelled data.
fig, ax = plt.subplots(1, 1, figsize=(3,3))
ax.axvline(x=0.0, color="xkcd:silver")
ax.axhline(y=0.0, color="xkcd:silver")
ax.scatter(X[idx_0,0], X[idx_0,1], marker="x", color="xkcd:red orange")
ax.scatter(X[idx_1,0], X[idx_1,1], marker="o", color="xkcd:ocean blue")
ax.set_axis_off()
fname = os.path.join(img_path, "sims_sinusoid.{}".format(my_ext))
plt.tight_layout()
plt.savefig(fname=fname)
plt.show()

# %% [markdown]
# ___
